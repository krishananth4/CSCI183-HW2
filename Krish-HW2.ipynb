# %% [markdown]
# 1) LOAD THE DIABETES DATASET

# %%
from sklearn.datasets import load_diabetes
import pandas as pd

diabetes_dataset = load_diabetes()
df = pd.DataFrame(data=diabetes_dataset.data, columns=diabetes_dataset.feature_names)
df['target'] = diabetes_dataset.target
df = df.head(442)
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# ...

# %% [markdown]
# 2) Identify the 4 Most Linearly Correlated Feature
# 3) Identify the 2 Features that do not have an association

# %%
from sklearn.datasets import load_diabetes
import pandas as pd

diabetes_dataset = load_diabetes()
df = pd.DataFrame(data=diabetes_dataset.data, columns=diabetes_dataset.feature_names)
df['target'] = diabetes_dataset.target
correlation_matrix = df.corr()
print(correlation_matrix)
correlation = df.corr()['target']
print(correlation)
# Out:
#              age       sex       bmi        bp        s1        s2        s3  \
# age     1.000000  0.173737  0.185085  0.335428  0.260061  0.219243 -0.075181
# sex     0.173737  1.000000  0.088161  0.241010  0.035277  0.142637 -0.379090
# bmi     0.185085  0.088161  1.000000  0.395411  0.249777  0.261170 -0.366811
# bp      0.335428  0.241010  0.395411  1.000000  0.242464  0.185548 -0.178762
# s1      0.260061  0.035277  0.249777  0.242464  1.000000  0.896663  0.051519
# s2      0.219243  0.142637  0.261170  0.185548  0.896663  1.000000 -0.196455
# s3     -0.075181 -0.379090 -0.366811 -0.178762  0.051519 -0.196455  1.000000
# s4      0.203841  0.332115  0.413807  0.257650  0.542207  0.659817 -0.738493
# s5      0.270774  0.149916  0.446157  0.393480  0.515503  0.318357 -0.398577
# s6      0.301731  0.208133  0.388680  0.390430  0.325717  0.290600 -0.273697
# target  0.187889  0.043062  0.586450  0.441482  0.212022  0.174054 -0.394789
#
# ...

# %%
correlation = df.corr()['target']
print(correlation)
correlation = correlation.drop('target')
print("Strongest Positive Linear Relationship: ", correlation.idxmax(), '-->', correlation.max())
print("Strongest Negative Linear Relationship: ", correlation.idxmin(), '-->', correlation.min())
print("No Association 1: ", 'sex', '-->',correlation['sex'])
print("No Association 2: ", 's2', '-->',correlation['s2'])
# Out:
# age       0.187889
# sex       0.043062
# bmi       0.586450
# bp        0.441482
# s1        0.212022
# s2        0.174054
# s3       -0.394789
# s4        0.430453
# s5        0.565883
# s6        0.382483
# target    1.000000
# Name: target, dtype: float64
# Strongest Positive Linear Relationship:  bmi --> 0.5864501344746885
# Strongest Negative Linear Relationship:  s3 --> -0.39478925067091836
# No Association 1:  sex --> 0.043061998451605396
# No Association 2:  s2 --> 0.1740535869687425

# %%
from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import pandas as pd
import matplotlib.pyplot as plt

diabetes_dataset = load_diabetes()
df = pd.DataFrame(data=diabetes_dataset.data, columns=diabetes_dataset.feature_names)
df['target'] = diabetes_dataset.target
y = df['target']
for cols in df.columns:
    x = df[[cols]]
    model = LinearRegression()
    model.fit(x,y)
    y_pred = model.predict(x)
    plt.scatter(x,y)
    plt.plot(x, y_pred, color='blue')
    plt.xlabel(cols)
    plt.ylabel('Target')
    plt.show()
    mean_squared_error_value = mean_squared_error(y, y_pred)
    print("MSE:", mean_squared_error_value)
    print("Regression Coefficient:", model.coef_)
    print("Intercept:", model.intercept_)
# Out:
# MSE: 5720.5470172056475
# Regression Coefficient: [304.18307453]
# Intercept: 152.13348416289594
# MSE: 5918.888899586022
# Regression Coefficient: [69.71535568]
# Intercept: 152.13348416289594
# MSE: 3890.456585461273
# Regression Coefficient: [949.43526038]
# Intercept: 152.13348416289617
# MSE: 4774.113902368687
# Regression Coefficient: [714.7382595]
# Intercept: 152.13348416289597
# MSE: 5663.315623739354
# Regression Coefficient: [343.25445189]
# Intercept: 152.13348416289594
# MSE: 5750.241102677782
# Regression Coefficient: [281.78459335]
# Intercept: 152.13348416289594
# MSE: 5005.661620710652
# Regression Coefficient: [-639.14527932]
# Intercept: 152.13348416289594
# MSE: 4831.13838643409
# Regression Coefficient: [696.88303009]
# Intercept: 152.13348416289594
# MSE: 4030.998722591287
# Regression Coefficient: [916.13737455]
# Intercept: 152.13348416289585
# MSE: 5062.380594520543
# Regression Coefficient: [619.22282068]
# Intercept: 152.13348416289594
# ...
